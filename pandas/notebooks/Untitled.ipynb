# %%
import pandas as pd

# %%
# read a dataset of Chipotle orders directly from a URL and store the results in a DataFrame
orders = pd.read_table('http://bit.ly/chiporders')

# %%
# ?pd.read_table

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
# read a dataset of movie reviewers (modifying the default parameter values for read_table)
user_cols = ['user_id', 'age', 'gender', 'occupation', 'zip_code']
users = pd.read_table('http://bit.ly/movieusers', sep='|', header=None, names=user_cols)

# %%
users.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
users = pd.read_table('http://bit.ly/movieusers', sep='|', header=None, columns=user_cols)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-e0fe6a0267e1> in <module>()
# ----> 1 users = pd.read_table('http://bit.ly/movieusers', sep='|', header=None, columns=user_cols)
#
# TypeError: parser_f() got an unexpected keyword argument 'columns'

# %%
# ?pd.read_table

# %%
# ?pd.read_csv

# %%
# read a dataset of UFO reports into a DataFrame
ufo = pd.read_table('http://bit.ly/uforeports', sep=',',)# header=0)

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
# create a new 'Location' Series (must use bracket notation to define the Series name)
ufo['Location'] = ufo.City + ', ' + ufo.State
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                    Location
# 0                Ithaca, NY
# 1           Willingboro, NJ
# 2               Holyoke, CO
# 3               Abilene, KS
# 4  New York Worlds Fair, NY

# %%
# read a dataset of top-rated IMDb movies into a DataFrame
movies = pd.read_csv('http://bit.ly/imdbratings')

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
type(movies.head)
# Out:
# method

# %%
type(movies.describe)
# Out:
# method

# %%
type(movies.star_rating)
# Out:
# pandas.core.series.Series

# %%
movies.mean()
# Out:
# star_rating      7.889785
# duration       120.979571
# dtype: float64

# %%
type(movies.mean())
# Out:
# pandas.core.series.Series

# %%
type(movies.mean)
# Out:
# method

# %%
type(movies.memory_usage)
# Out:
# method

# %%
movies
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
movies.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
movies.plot(movies.star_rating, movies.duration)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-6464d8433ef9> in <module>()
# ----> 1 movies.plot(movies.star_rating, movies.duration)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# ...

# %%
movies.plot(x='star_rating', y='duration', marker='.', linewidth=0)

# %%
# ?movies.describe

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.describe(include=['object'])
# Out:
#             title content_rating  genre  \
# count         979            976    979
# unique        975             12     16
# top     True Grit              R  Drama
# freq            2            460    278
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %%
movies[movies['title']=='True Grit']
# Out:
#      star_rating      title content_rating      genre  duration  \
# 662          7.7  True Grit          PG-13  Adventure       110
# 936          7.4  True Grit            NaN  Adventure       128
#
#                                            actors_list
# 662  [u'Jeff Bridges', u'Matt Damon', u'Hailee Stei...
# 936    [u'John Wayne', u'Kim Darby', u'Glen Campbell']

# %%
len( movies.actors_list[0] )
# Out:
# 50

# %%
ufo = pd.read_csv('http://bit.ly/uforeports')

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
# rename two of the columns by using the 'rename' method
ufo.rename(columns={'Colors Reported':'Colors_Reported', 'Shape Reported':'Shape_Reported'}, inplace=True)
ufo.columns

# %%
ufo_cols = ['city', 'colors reported', 'shape reported', 'state', 'time']
ufo.columns = ufo_cols
ufo.columns
# Out:
# Index(['city', 'colors reported', 'shape reported', 'state', 'time'], dtype='object')

# %%
ufo.columns = ufo.columns.str.replace(' ', '_')

# %%
ufo.columns
# Out:
# Index(['City', 'Colors_Reported', 'Shape_Reported', 'State', 'Time'], dtype='object')

# %%
# read a dataset of UFO reports into a DataFrame
ufo = pd.read_csv('http://bit.ly/uforeports')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
del ufo['Colors Reported']

# %%
ufo.head()
# Out:
#                    City Shape Reported State             Time
# 0                Ithaca       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke           OVAL    CO  2/15/1931 14:00
# 3               Abilene           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair          LIGHT    NY  4/18/1933 19:00

# %%
# read a dataset of UFO reports into a DataFrame
ufo = pd.read_csv('http://bit.ly/uforeports')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.pop('Colors Reported')
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          RED
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          RED
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
#           ...
# 18211       NaN
# 18212       NaN
# 18213     GREEN
# 18214       NaN
# 18215       NaN
# 18216    ORANGE
# 18217       NaN
# 18218       NaN
# 18219       NaN
# 18220      BLUE
# 18221       NaN
# 18222       NaN
# 18223       NaN
# 18224       NaN
# 18225       NaN
# 18226       NaN
# 18227       NaN
# 18228       NaN
# 18229       NaN
# 18230       NaN
# 18231       NaN
# 18232       NaN
# 18233       RED
# 18234       NaN
# ...

# %%
ufo.head()
# Out:
#                    City Shape Reported State             Time
# 0                Ithaca       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke           OVAL    CO  2/15/1931 14:00
# 3               Abilene           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair          LIGHT    NY  4/18/1933 19:00

# %%
# read a dataset of UFO reports into a DataFrame
ufo = pd.read_csv('http://bit.ly/uforeports')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.drop('Colors Reported', axis=1, inplace=True)
ufo.head()
# Out:
#                    City Shape Reported State             Time
# 0                Ithaca       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke           OVAL    CO  2/15/1931 14:00
# 3               Abilene           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair          LIGHT    NY  4/18/1933 19:00

# %%
# remove multiple columns at once
ufo.drop(['City', 'State'], axis=1, inplace=True)
ufo.head()
# Out:
#   Shape Reported             Time
# 0       TRIANGLE   6/1/1930 22:00
# 1          OTHER  6/30/1930 20:00
# 2           OVAL  2/15/1931 14:00
# 3           DISK   6/1/1931 13:00
# 4          LIGHT  4/18/1933 19:00

# %%
# read a dataset of UFO reports into a DataFrame
ufo = pd.read_csv('http://bit.ly/uforeports')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
del ufo['City'], ufo['Colors Reported']

# %%
ufo.head()
# Out:
#   Shape Reported State             Time
# 0       TRIANGLE    NY   6/1/1930 22:00
# 1          OTHER    NJ  6/30/1930 20:00
# 2           OVAL    CO  2/15/1931 14:00
# 3           DISK    KS   6/1/1931 13:00
# 4          LIGHT    NY  4/18/1933 19:00

# %%
# read a dataset of UFO reports into a DataFrame
ufo = pd.read_csv('http://bit.ly/uforeports')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
del ufo[ufo.index == 1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-105-d25fe74a8a22> in <module>()
# ----> 1 del ufo[ufo.index == 1]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __delitem__(self, key)
#    2741             # there was no match, this call should raise the appropriate
#    2742             # exception:
# -> 2743             self._data.delete(key)
#    2744
#    2745         # delete from the caches
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in delete(self, item)
#    4172         Delete selected item (items if non-unique) in-place.
#    4173         """
# -> 4174         indexer = self.items.get_loc(item)
#    4175
#    4176         is_deleted = np.zeros(self.shape[0], dtype=np.bool_)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
# ...

# %%
ufo.drop([0,2,7], axis=0, inplace=True)

# %%
ufo.index = range(0, len(ufo))

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 1               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 2  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
# 3           Valley City             NaN           DISK    ND  9/15/1934 15:30
# 4           Crater Lake             NaN         CIRCLE    CA   6/15/1935 0:00

# %%
ufo.drop(['City','Colors Reported'], axis=1, inplace=True)

# %%
ufo.head()
# Out:
#   Shape Reported State             Time
# 0          OTHER    NJ  6/30/1930 20:00
# 1           DISK    KS   6/1/1931 13:00
# 2          LIGHT    NY  4/18/1933 19:00
# 3           DISK    ND  9/15/1934 15:30
# 4         CIRCLE    CA   6/15/1935 0:00

# %%
# read a dataset of top-rated IMDb movies into a DataFrame
movies = pd.read_csv('http://bit.ly/imdbratings')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
best = movies.sort_values(by='star_rating', ascending=False)

# %%
worst = movies.sort_values(by='star_rating', ascending=True)

# %%
worst.head()
# Out:
#      star_rating        title content_rating   genre  duration  \
# 978          7.4  Wall Street              R   Crime       126
# 950          7.4        Bound              R   Crime       108
# 949          7.4   Home Alone             PG  Comedy       103
# 948          7.4   Frances Ha              R  Comedy        86
# 947          7.4   Eraserhead        UNRATED   Drama        89
#
#                                            actors_list
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
# 950  [u'Jennifer Tilly', u'Gina Gershon', u'Joe Pan...
# 949  [u'Macaulay Culkin', u'Joe Pesci', u'Daniel St...
# 948  [u'Greta Gerwig', u'Mickey Sumner', u'Adam Dri...
# 947  [u'Jack Nance', u'Charlotte Stewart', u'Allen ...

# %%
movies.title.sort_values().head()
# Out:
# 542     (500) Days of Summer
# 5               12 Angry Men
# 201         12 Years a Slave
# 698                127 Hours
# 110    2001: A Space Odyssey
# Name: title, dtype: object

# %%
movies.describe(include=['object'])
# Out:
#             title content_rating  genre  \
# count         979            976    979
# unique        975             12     16
# top     True Grit              R  Drama
# freq            2            460    278
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %%
movies.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.sort_values(by=['content_rating','duration'])
# Out:
#      star_rating                               title content_rating  \
# 713          7.6                     The Jungle Book       APPROVED
# 513          7.8      Invasion of the Body Snatchers       APPROVED
# 272          8.1                         The Killing       APPROVED
# 703          7.6                             Dracula       APPROVED
# 612          7.7                  A Hard Day's Night       APPROVED
# 58           8.5                      Paths of Glory       APPROVED
# 210          8.1                               Laura       APPROVED
# 656          7.7     Snow White and the Seven Dwarfs       APPROVED
# 844          7.5                           Pinocchio       APPROVED
# 233          8.1             The Night of the Hunter       APPROVED
# 287          8.1                     His Girl Friday       APPROVED
# 484          7.8       The Day the Earth Stood Still       APPROVED
# 451          7.9              Miracle on 34th Street       APPROVED
# ...

# %%
# sort the DataFrame first by 'content_rating', then by 'duration'
movies = pd.read_csv('http://bit.ly/imdbratings')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
booleans = (movies.duration >= 200.0).tolist()
is_long = pd.Series(booleans)

# %%
movies[is_long]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
booleans = (movies.duration >= 100.0).tolist()

# %%
bools = pd.Series(booleans)

# %%
movies.head()
# Out:
#      star_rating                        title content_rating    genre  \
# 389          8.0                       Freaks        UNRATED    Drama
# 338          8.0          Battleship Potemkin        UNRATED  History
# 258          8.1  The Cabinet of Dr. Caligari        UNRATED    Crime
# 293          8.1                    Duck Soup         PASSED   Comedy
# 88           8.4                      The Kid      NOT RATED   Comedy
#
#      duration                                        actors_list
# 389        64  [u'Wallace Ford', u'Leila Hyams', u'Olga Bacla...
# 338        66  [u'Aleksandr Antonov', u'Vladimir Barsky', u'G...
# 258        67  [u'Werner Krauss', u'Conrad Veidt', u'Friedric...
# 293        68    [u'Groucho Marx', u'Harpo Marx', u'Chico Marx']
# 88         68  [u'Charles Chaplin', u'Edna Purviance', u'Jack...

# %%
bools
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 949     True
# 950     True
# 951     True
# 952     True
# 953     True
# 954     True
# 955     True
# 956     True
# 957     True
# 958     True
# 959     True
# 960     True
# 961     True
# 962     True
# 963     True
# 964     True
# 965     True
# 966     True
# 967     True
# 968     True
# 969     True
# 970     True
# 971     True
# 972     True
# 973     True
# 974     True
# 975     True
# 976     True
# 977     True
# 978     True
# Length: 979, dtype: bool

# %%
movies = pd.read_csv('http://bit.ly/imdbratings')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
booleans = []
for length in movies.duration:
    if length >= 200:
        booleans.append(True)
    else:
        booleans.append(False)

# %%
is_long = pd.Series(booleans)
is_long.head()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies[is_long]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
movies[ movies.duration > 200.0 ].genre
# Out:
# 7      Adventure
# 17         Drama
# 78         Crime
# 85     Adventure
# 142    Adventure
# 157        Drama
# 204    Adventure
# 445    Adventure
# 476        Drama
# 630    Biography
# 767       Action
# Name: genre, dtype: object

# %%
long_movies = movies[ movies.duration > 200.0 ]

# %%
long_movies
# Out:
#      star_rating                                          title  \
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 17         UNRATED      Drama       207
# 78               R      Crime       229
# ...

# %%
# read a dataset of top-rated IMDb movies into a DataFrame
movies = pd.read_csv('http://bit.ly/imdbratings')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
booleans = (movies.duration >= 100.0).tolist()

# %%
person = 'Elijah Wood'
booleans = [person in actors for actors in movies.actors_list]
booleans = pd.Series(booleans)
elijah_wood_movies = movies[booleans]
elijah_wood_movies
# Out:
#      star_rating                                              title  \
# 7            8.9      The Lord of the Rings: The Return of the King
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 14           8.8              The Lord of the Rings: The Two Towers
# 830          7.5                             Green Street Hooligans
# 868          7.5                          Everything Is Illuminated
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 10           PG-13  Adventure       178
# 14           PG-13  Adventure       179
# 830              R      Crime       109
# 868          PG-13     Comedy       106
#
#                                            actors_list
# 7    [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 10   [u'Elijah Wood', u'Ian McKellen', u'Orlando Bl...
# 14   [u'Elijah Wood', u'Ian McKellen', u'Viggo Mort...
# 830  [u'Elijah Wood', u'Charlie Hunnam', u'Claire F...
# ...

# %%
elijah_wood_movies = movies[ movies.actors_list.str.contains('Elijah Wood') ]
elijah_wood_movies
# Out:
#      star_rating                                              title  \
# 7            8.9      The Lord of the Rings: The Return of the King
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 14           8.8              The Lord of the Rings: The Two Towers
# 830          7.5                             Green Street Hooligans
# 868          7.5                          Everything Is Illuminated
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 10           PG-13  Adventure       178
# 14           PG-13  Adventure       179
# 830              R      Crime       109
# 868          PG-13     Comedy       106
#
#                                            actors_list
# 7    [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 10   [u'Elijah Wood', u'Ian McKellen', u'Orlando Bl...
# 14   [u'Elijah Wood', u'Ian McKellen', u'Viggo Mort...
# 830  [u'Elijah Wood', u'Charlie Hunnam', u'Claire F...
# ...

# %%
booleans = []
person = 'Elijah Wood'
for persons in movies.actors_list:
    if person in persons:
        booleans.append(True)
    else:
        booleans.append(False)

# %%
booleans
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
# ...

# %%
movies[pd.Series(booleans)]
# Out:
#      star_rating                                              title  \
# 7            8.9      The Lord of the Rings: The Return of the King
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 14           8.8              The Lord of the Rings: The Two Towers
# 830          7.5                             Green Street Hooligans
# 868          7.5                          Everything Is Illuminated
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 10           PG-13  Adventure       178
# 14           PG-13  Adventure       179
# 830              R      Crime       109
# 868          PG-13     Comedy       106
#
#                                            actors_list
# 7    [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 10   [u'Elijah Wood', u'Ian McKellen', u'Orlando Bl...
# 14   [u'Elijah Wood', u'Ian McKellen', u'Viggo Mort...
# 830  [u'Elijah Wood', u'Charlie Hunnam', u'Claire F...
# ...

# %%
movies[kim]
# Out:
#      star_rating                                              title  \
# 7            8.9      The Lord of the Rings: The Return of the King
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 14           8.8              The Lord of the Rings: The Two Towers
# 830          7.5                             Green Street Hooligans
# 868          7.5                          Everything Is Illuminated
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 10           PG-13  Adventure       178
# 14           PG-13  Adventure       179
# 830              R      Crime       109
# 868          PG-13     Comedy       106
#
#                                            actors_list
# 7    [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 10   [u'Elijah Wood', u'Ian McKellen', u'Orlando Bl...
# 14   [u'Elijah Wood', u'Ian McKellen', u'Viggo Mort...
# 830  [u'Elijah Wood', u'Charlie Hunnam', u'Claire F...
# ...

# %%
indices_of_long_movies = movies[movies.duration > 200.0].index

# %%
indices_of_long_movies
# Out:
# Int64Index([7, 17, 78, 85, 142, 157, 204, 445, 476, 630, 767], dtype='int64')

# %%
movies.loc[movies.duration > 200.0]
# Out:
#      star_rating                                          title  \
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 17         UNRATED      Drama       207
# 78               R      Crime       229
# ...

# %%
movies[movies.duration > 200.0]['genre']
# Out:
# 7      Adventure
# 17         Drama
# 78         Crime
# 85     Adventure
# 142    Adventure
# 157        Drama
# 204    Adventure
# 445    Adventure
# 476        Drama
# 630    Biography
# 767       Action
# Name: genre, dtype: object

# %%
movies.loc[movies.duration > 200.0, 'genre']
# Out:
# 7      Adventure
# 17         Drama
# 78         Crime
# 85     Adventure
# 142    Adventure
# 157        Drama
# 204    Adventure
# 445    Adventure
# 476        Drama
# 630    Biography
# 767       Action
# Name: genre, dtype: object

# %%
movies = pd.read_csv('http://bit.ly/imdbratings')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies[(movies.duration >= 200) & (movies.genre == 'Adventure')]
# Out:
#      star_rating                                          title  \
# 7            8.9  The Lord of the Rings: The Return of the King
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 85              PG  Adventure       216
# 142             PG  Adventure       224
# 204              G  Adventure       212
# 445       APPROVED  Adventure       220
#
#                                            actors_list
# 7    [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 85   [u"Peter O'Toole", u'Alec Guinness', u'Anthony...
# 142  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...
# 204  [u'Charlton Heston', u'Jack Hawkins', u'Stephe...
# 445  [u'Charlton Heston', u'Yul Brynner', u'Anne Ba...

# %%
movies[(movies.duration >= 200) | (movies.genre == 'Crime')]
# Out:
#      star_rating                                          title  \
# 0            9.3                       The Shawshank Redemption
# 1            9.2                                  The Godfather
# 2            9.1                         The Godfather: Part II
# 4            8.9                                   Pulp Fiction
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 21           8.7                                    City of God
# 23           8.7                             The Usual Suspects
# 28           8.6                         Leon: The Professional
# 34           8.6                             American History X
# 40           8.5                                 The Green Mile
# 49           8.5                                   The Departed
# 63           8.4                                              M
# 65           8.4                    Witness for the Prosecution
# ...

# %%
movies[(movies.genre == 'Crime') | (movies.genre == 'Drama') | (movies.genre == 'Action')].head(2)
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']

# %%
movies[movies.genre.isin(['Crime', 'Drama', 'Action'])]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# 5            8.9                                     12 Angry Men
# 9            8.9                                       Fight Club
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 13           8.8                                     Forrest Gump
# 16           8.7                  One Flew Over the Cuckoo's Nest
# 17           8.7                                    Seven Samurai
# 19           8.7                                        Star Wars
# ...

# %%
# read a dataset of UFO reports into a DataFrame, and check the columns
ufo = pd.read_csv('http://bit.ly/uforeports')
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo = pd.read_csv('http://bit.ly/uforeports', usecols=['City', 'State'])
ufo.head()
# Out:
#                    City State
# 0                Ithaca    NY
# 1           Willingboro    NJ
# 2               Holyoke    CO
# 3               Abilene    KS
# 4  New York Worlds Fair    NY

# %%
ufo = pd.read_csv('http://bit.ly/uforeports')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo = pd.read_table('http://bit.ly/uforeports', sep=',', usecols=['City', 'State'])
ufo.head()
# Out:
#                    City State
# 0                Ithaca    NY
# 1           Willingboro    NJ
# 2               Holyoke    CO
# 3               Abilene    KS
# 4  New York Worlds Fair    NY

# %%
ufo = pd.read_csv('http://bit.ly/uforeports', usecols=[0, 4])
ufo.head()
# Out:
#                    City             Time
# 0                Ithaca   6/1/1930 22:00
# 1           Willingboro  6/30/1930 20:00
# 2               Holyoke  2/15/1931 14:00
# 3               Abilene   6/1/1931 13:00
# 4  New York Worlds Fair  4/18/1933 19:00

# %%
# specify how many rows to read
ufo = pd.read_csv('http://bit.ly/uforeports', nrows=10)
ufo
# Out:
#                    City  Colors Reported Shape Reported State  \
# 0                Ithaca              NaN       TRIANGLE    NY
# 1           Willingboro              NaN          OTHER    NJ
# 2               Holyoke              NaN           OVAL    CO
# 3               Abilene              NaN           DISK    KS
# 4  New York Worlds Fair              NaN          LIGHT    NY
# 5           Valley City              NaN           DISK    ND
# 6           Crater Lake              NaN         CIRCLE    CA
# 7                  Alma              NaN           DISK    MI
# 8               Eklutna              NaN          CIGAR    AK
# 9               Hubbard              NaN       CYLINDER    OR
#
#                Time
# 0    6/1/1930 22:00
# 1   6/30/1930 20:00
# 2   2/15/1931 14:00
# 3    6/1/1931 13:00
# 4   4/18/1933 19:00
# 5   9/15/1934 15:30
# 6    6/15/1935 0:00
# 7    7/15/1936 0:00
# 8  10/15/1936 17:00
# 9    6/15/1937 0:00

# %%
ufo
# Out:
#                    City  Colors Reported Shape Reported State  \
# 0                Ithaca              NaN       TRIANGLE    NY
# 1           Willingboro              NaN          OTHER    NJ
# 2               Holyoke              NaN           OVAL    CO
# 3               Abilene              NaN           DISK    KS
# 4  New York Worlds Fair              NaN          LIGHT    NY
# 5           Valley City              NaN           DISK    ND
# 6           Crater Lake              NaN         CIRCLE    CA
# 7                  Alma              NaN           DISK    MI
# 8               Eklutna              NaN          CIGAR    AK
# 9               Hubbard              NaN       CYLINDER    OR
#
#                Time
# 0    6/1/1930 22:00
# 1   6/30/1930 20:00
# 2   2/15/1931 14:00
# 3    6/1/1931 13:00
# 4   4/18/1933 19:00
# 5   9/15/1934 15:30
# 6    6/15/1935 0:00
# 7    7/15/1936 0:00
# 8  10/15/1936 17:00
# 9    6/15/1937 0:00

# %%
# various methods are available to iterate through a DataFrame
for index, row in ufo.iterrows():
    print(index, row.City, row.State)
# Out:
# 0 Ithaca NY
# 1 Willingboro NJ
# 2 Holyoke CO
# 3 Abilene KS
# 4 New York Worlds Fair NY
# 5 Valley City ND
# 6 Crater Lake CA
# 7 Alma MI
# 8 Eklutna AK
# 9 Hubbard OR

# %%
for index,row in ufo.iterrows():
    print(index, row.City)
# Out:
# 0 Ithaca
# 1 Willingboro
# 2 Holyoke
# 3 Abilene
# 4 New York Worlds Fair
# 5 Valley City
# 6 Crater Lake
# 7 Alma
# 8 Eklutna
# 9 Hubbard

# %%
k = ufo.iterrows()

# %%
for index,row in ufo.iterrows():
    print(index, row.City, row.State)
# Out:
# 0 Ithaca NY
# 1 Willingboro NJ
# 2 Holyoke CO
# 3 Abilene KS
# 4 New York Worlds Fair NY
# 5 Valley City ND
# 6 Crater Lake CA
# 7 Alma MI
# 8 Eklutna AK
# 9 Hubbard OR

# %%
# read a dataset of alcohol consumption into a DataFrame, and check the data types
drinks = pd.read_csv('http://bit.ly/drinksbycountry')
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
d = drinks.select_dtypes(include=['int64', 'float64'])

# %%
d.head()
# Out:
#    beer_servings  spirit_servings  wine_servings  total_litres_of_pure_alcohol
# 0              0                0              0                           0.0
# 1             89              132             54                           4.9
# 2             25                0             14                           0.7
# 3            245              138            312                          12.4
# 4            217               57             45                           5.9

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
# drop a row (temporarily)
drinks.drop(2, axis=0).head()
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
#
#    total_litres_of_pure_alcohol      continent
# 0                           0.0           Asia
# 1                           4.9         Europe
# 3                          12.4         Europe
# 4                           5.9         Africa
# 5                           4.9  North America

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.mean()
# Out:
# beer_servings                   106.160622
# spirit_servings                  80.994819
# wine_servings                    49.450777
# total_litres_of_pure_alcohol      4.717098
# dtype: float64

# %%
drinks.mean(axis='index')
# Out:
# beer_servings                   106.160622
# spirit_servings                  80.994819
# wine_servings                    49.450777
# total_litres_of_pure_alcohol      4.717098
# dtype: float64

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
# read a dataset of Chipotle orders into a DataFrame
orders = pd.read_table('http://bit.ly/chiporders')
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
orders.item_name.str.upper().head()
# Out:
# 0             CHIPS AND FRESH TOMATO SALSA
# 1                                     IZZE
# 2                         NANTUCKET NECTAR
# 3    CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 4                             CHICKEN BOWL
# Name: item_name, dtype: object

# %%
orders.item_price.str.upper().head()
# Out:
# 0     $2.39
# 1     $3.39
# 2     $3.39
# 3     $2.39
# 4    $16.98
# Name: item_price, dtype: object

# %%
orders.item_name.str.contains('Chicken').head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: item_name, dtype: bool

# %%
chicken_orders = orders.item_name.str.contains('Chicken').head()

# %%
chicken_orders
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: item_name, dtype: bool

# %%
orders.choice_description.

# %%
orders.choice_description.str.replace('[', '').str.replace(']', '').head()
# Out:
# 0                                                  NaN
# 1                                           Clementine
# 2                                                Apple
# 3                                                  NaN
# 4    Tomatillo-Red Chili Salsa (Hot), Black Beans, ...
# Name: choice_description, dtype: object

# %%
[str(i).replace('[', '').replace(']', '') for i in orders.choice_description.tolist()]
# Out:
# ['nan',
#  'Clementine',
#  'Apple',
#  'nan',
#  'Tomatillo-Red Chili Salsa (Hot), Black Beans, Rice, Cheese, Sour Cream',
#  'Fresh Tomato Salsa (Mild), Rice, Cheese, Sour Cream, Guacamole, Lettuce',
#  'nan',
#  'Tomatillo Red Chili Salsa, Fajita Vegetables, Black Beans, Pinto Beans, Cheese, Sour Cream, Guacamole, Lettuce',
#  'Tomatillo Green Chili Salsa, Pinto Beans, Cheese, Sour Cream, Lettuce',
#  'Fresh Tomato Salsa, Rice, Black Beans, Pinto Beans, Cheese, Sour Cream, Lettuce',
#  'nan',
#  'Roasted Chili Corn Salsa, Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream',
#  'Roasted Chili Corn Salsa, Rice, Black Beans, Cheese, Sour Cream',
#  'Fresh Tomato Salsa, Fajita Vegetables, Rice, Cheese, Sour Cream, Guacamole',
#  'nan',
#  'nan',
#  'Tomatillo-Green Chili Salsa (Medium), Pinto Beans, Cheese, Sour Cream',
#  'Fresh Tomato Salsa (Mild), Black Beans, Rice, Cheese, Sour Cream, Lettuce',
#  'Sprite',
# ...

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
orders.choice_description.str.replace('[', '').str.replace(']', '').head()
# Out:
# 0                                                  NaN
# 1                                           Clementine
# 2                                                Apple
# 3                                                  NaN
# 4    Tomatillo-Red Chili Salsa (Hot), Black Beans, ...
# Name: choice_description, dtype: object

# %%
orders.choice_description.head()
# Out:
# 0                                                  NaN
# 1                                         [Clementine]
# 2                                              [Apple]
# 3                                                  NaN
# 4    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# Name: choice_description, dtype: object

# %%
orders.choice_description = orders.choice_description.str.replace('[', '').str.replace(']', '').head()

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                         Clementine     $3.39
# 2                                              Apple     $3.39
# 3                                                NaN     $2.39
# 4  Tomatillo-Red Chili Salsa (Hot), Black Beans, ...    $16.98

# %%
orders = pd.read_table('http://bit.ly/chiporders')
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
# many pandas string methods support regular expressions (regex)
orders.choice_description.str.replace('[\[\]]', '').head()
# Out:
# 0                                                  NaN
# 1                                           Clementine
# 2                                                Apple
# 3                                                  NaN
# 4    Tomatillo-Red Chili Salsa (Hot), Black Beans, ...
# Name: choice_description, dtype: object

# %%
# many pandas string methods support regular expressions (regex)
orders.choice_description.str.replace('[\]]', '').head()
# Out:
# 0                                                  NaN
# 1                                          [Clementine
# 2                                               [Apple
# 3                                                  NaN
# 4    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# Name: choice_description, dtype: object

# %%
# many pandas string methods support regular expressions (regex)
orders.choice_description.str.replace('[\[]', '').head()
# Out:
# 0                                                  NaN
# 1                                          Clementine]
# 2                                               Apple]
# 3                                                  NaN
# 4    Tomatillo-Red Chili Salsa (Hot), Black Beans, ...
# Name: choice_description, dtype: object

# %%
# many pandas string methods support regular expressions (regex)
orders.choice_description.str.replace('[\]\[]', '').head()
# Out:
# 0                                                  NaN
# 1                                           Clementine
# 2                                                Apple
# 3                                                  NaN
# 4    Tomatillo-Red Chili Salsa (Hot), Black Beans, ...
# Name: choice_description, dtype: object

# %%
# many pandas string methods support regular expressions (regex)
orders.choice_description.str.replace('[\[\]]', '').head()
# Out:
# 0                                                  NaN
# 1                                           Clementine
# 2                                                Apple
# 3                                                  NaN
# 4    Tomatillo-Red Chili Salsa (Hot), Black Beans, ...
# Name: choice_description, dtype: object

# %%
# read a dataset of alcohol consumption into a DataFrame
drinks = pd.read_csv('http://bit.ly/drinksbycountry')
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks.beer_servings.dtype
# Out:
# dtype('int64')

# %%
drinks.beer_servings =  drinks.beer_servings.astype(float)

# %%
# change the data type of an existing Series
#drinks['beer_servings'] = drinks.beer_servings.astype(float)
drinks.dtypes
# Out:
# country                          object
# beer_servings                   float64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0                0              0
# 1      Albania           89.0              132             54
# 2      Algeria           25.0                0             14
# 3      Andorra          245.0              138            312
# 4       Angola          217.0               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.beer_servings = drinks.beer_servings.astype(str)

# %%
drinks.head()
# Out:
#        country beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan           0.0                0              0
# 1      Albania          89.0              132             54
# 2      Algeria          25.0                0             14
# 3      Andorra         245.0              138            312
# 4       Angola         217.0               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                    object
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks.beer_servings.dtype
# Out:
# dtype('O')

# %%
drinks.country.dtype
# Out:
# dtype('O')

# %%
drinks.beer_servings.astype(object)
# Out:
# 0        0.0
# 1       89.0
# 2       25.0
# 3      245.0
# 4      217.0
# 5      102.0
# 6      193.0
# 7       21.0
# 8      261.0
# 9      279.0
# 10      21.0
# 11     122.0
# 12      42.0
# 13       0.0
# 14     143.0
# 15     142.0
# 16     295.0
# 17     263.0
# 18      34.0
# 19      23.0
# 20     167.0
# 21      76.0
# 22     173.0
# 23     245.0
# 24      31.0
# 25     231.0
# 26      25.0
# 27      88.0
# 28      37.0
# 29     144.0
#        ...
# 163    128.0
# 164     90.0
# 165    152.0
# 166    185.0
# 167      5.0
# 168      2.0
# 169     99.0
# 170    106.0
# 171      1.0
# 172     36.0
# 173     36.0
# 174    197.0
# 175     51.0
# 176     51.0
# 177     19.0
# 178      6.0
# 179     45.0
# 180    206.0
# 181     16.0
# 182    219.0
# 183     36.0
# 184    249.0
# 185    115.0
# 186     25.0
# 187     21.0
# 188    333.0
# 189    111.0
# 190      6.0
# 191     32.0
# 192     64.0
# Name: beer_servings, Length: 193, dtype: object

# %%
drinks.beer_servings = drinks.beer_servings.astype(float)

# %%
drinks.beer_servings.dtype
# Out:
# dtype('float64')

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0                0              0
# 1      Albania           89.0              132             54
# 2      Algeria           25.0                0             14
# 3      Andorra          245.0              138            312
# 4       Angola          217.0               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.beer_servings = drinks.beer_servings.astype(object)

# %%
drinks.head()
# Out:
#        country beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan             0                0              0
# 1      Albania            89              132             54
# 2      Algeria            25                0             14
# 3      Andorra           245              138            312
# 4       Angola           217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa
